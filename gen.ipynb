# %%
import requests  
import re          
u2=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ABCG2%C2%A0+bos+taurus") 
gen1=re.findall(r'(Chromosome.+3215.)',u2.text)
u4=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ACO2%C2%A0+bos+taurus") 
gen3=re.findall(r'(Chromosome.+183.)',u4.text)
u6=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ADAMTS12%C2%A0%C2%A0+bos+taurus") 
gen5=re.findall(r'(Chromosome.+8041.)',u6.text)
u7=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ADGRB1%C2%A0%C2%A0+bos+taurus") 
gen6=re.findall(r'(Chromosome.+4927.............)',u7.text)
u11=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=AGBL4%C2%A0+bos+taurus") 
gen10=re.findall(r'(Chromosome.+3389.)',u11.text)
u12=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=AGO2+bos+taurus") 
gen11=re.findall(r'(Chromosome.+8228.)',u12.text)
u15=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ANKRD17+bos+taurus") 
gen14=re.findall(r'(Chromosome.+5145.............)',u15.text)
u16=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ANKRD52+bos+taurus") 
gen15=re.findall(r'(Chromosome.+6731.)',u16.text)
u17=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ANO6+bos+taurus") 
gen16=re.findall(r'(Chromosome.+0394.............)',u17.text)
u18=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ARFGEF1+bos+taurus") 
gen17=re.findall(r'(Chromosome.+6714.............)',u18.text)

data1=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=PUS7L%C2%A0bos+taurus") 
gen511=re.findall(r'(Chromosome.+9838.)',data1.text) # se extrae las dependencias usando las expresiones regulares

data2=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RAB3IP+bos+taurus") 
gen512=re.findall(r'(Chromosome.+3681.............)',data2.text)

data3=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RAI14+bos+taurus") 
gen513=re.findall(r'(Chromosome.+261.............)',data3.text)
data5=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RASSF6+bos+taurus") 
gen515=re.findall(r'(Chromosome.+5809.............)',data5.text)
data6=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RBBP8NL+bos+taurus") 
gen516=re.findall(r'Chromosome.+34.<',data6.text)
data7=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RETSAT+bos+taurus") 
gen517=re.findall(r'Chromosome.+929.<',data7.text)
data8=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RHPN1+bos+taurus") 
gen518=re.findall(r'(Chromosome.+333.............)',data8.text)
data20=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RICTOR+bos+taurus") 
gen520=re.findall(r'Chromosome.+729.<',data20.text)
data11=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=ROBO1+bos+taurus") 
gen521=re.findall(r'(Chromosome.+505.............)',data11.text)
data12=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RPAP3+bos+taurus") 
gen522=re.findall(r'(Chromosome.+746.)',data12.text)
data12=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RPAP3+bos+taurus") 
gen522=re.findall(r'(Chromosome.+746.)',data12.text)
data13=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RPL23A+bos+taurus") 
gen523=re.findall(r'(Chromosome.+657.)',data13.text)
data14=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=RUNX2+bos+taurus") 
gen543=re.findall(r'(Chromosome.+540.)',data14.text)
data15=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SAA2+bos+taurus") 
gen544=re.findall(r'NC.*461868',data15.text)
data16=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SCD+bos+taurus") 
gen556=re.findall(r'(Chromosome.+9185.)',data16.text)
data17=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SCRIB+bos+taurus") 
gen557=re.findall(r'(Chromosome.+715.)',data17.text)
data18=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SCRT1+bos+taurus") 
gen558=re.findall(r'(Chromosome.+937.)',data18.text)
data19=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SELL%C2%A0+bos+taurus") 
gen559=re.findall(r'(Chromosome.+5774.............)',data19.text)
data20=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SELP%C2%A0+bos+taurus") 
gen561=re.findall(r'(Chromosome.+5051.............)',data20.text)
data21=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SERPINA14%C2%A0+bos+taurus") 
gen565=re.findall(r'(Chromosome.+2290.............)',data21.text)

data22=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SERPINA14%C2%A0+bos+taurus") 
gen566=re.findall(r'(Chromosome.+2290.............)',data22.text)

data23=requests.get("https://www.ncbi.nlm.nih.gov/gene/?term=SESN2+bos+taurus") 
gen567=re.findall(r'(Chromosome.+1785.............)',data23.text)


print(gen1)
print(gen3)
print(gen5)
print(gen6)
print(gen10)
print(gen11)
print(gen14)
print(gen15)
print(gen16)
print(gen17)
print(gen511)
print(gen512)
print(gen513)
print(gen515)
print(gen516)
print(gen517)
print(gen518)
print(gen520)
print(gen521)
print(gen522)
print(gen543)
print(gen544)
print(gen556)
print(gen557)
print(gen558)
print(gen559)
print(gen561)
print(gen565)
print(gen566)
print(gen567)
# Out:
# ['Chromosome 6, NC_037333.1 (36475491..36603215)']
# ['Chromosome 5, NC_037332.1 (112568137..112617183)']
# ['Chromosome 20, NC_037347.1 (39873389..40268041)']
# ['Chromosome 14, NC_037341.1 (1797345..1874927, complement)']
# ['Chromosome 3, NC_037330.1 (96267287..97733389)']
# ['Chromosome 14, NC_037341.1 (3100810..3138228)']
# ['Chromosome 6, NC_037333.1 (88187894..88355145, complement)']
# ['Chromosome 5, NC_037332.1 (57074892..57086731)']
# ['Chromosome 5, NC_037332.1 (34875294..35110394, complement)']
# ['Chromosome 14, NC_037341.1 (31327957..31456714, complement)']
# ['Chromosome 5, NC_037332.1 (36708358..36729838)']
# ['Chromosome 5, NC_037332.1 (43657003..43713681, complement)']
# ['Chromosome 20, NC_037347.1 (39313061..39475261, complement)']
# ['Chromosome 6, NC_037333.1 (88620412..88695809, complement)']
# ['Chromosome 13, NC_037340.1 (54837560..54852334)<']
# ['Chromosome 11, NC_037338.1 (49642200..49656929)<']
# ...
